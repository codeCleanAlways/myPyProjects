# %%
import pandas as pd
import numpy as np

dfOutcomes = pd.read_csv("sc1_Phase1_GE_Outcome.tsv",sep="\t")
dfOutcomes.describe()
# Out:
#        SURVIVAL_STATUS
# count       377.000000
# mean          0.864721
# std           0.342475
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000

# %%
dfFeatures = pd.read_csv("sc1_Phase1_GE_FeatureMatrix.tsv",sep="\t")
dfFeatures.head()
# Out:
#      PATIENTID      A1BG  A1BG.AS1      A1CF        A2M   A2M.AS1     A2ML1  \
# 0  patient_290  6.557793  6.453623  5.302909  12.530607  6.082401  5.667769
# 1  patient_394  6.323015  6.305724  5.552097  13.000489  6.263721  5.347906
# 2   patient_81  6.669421  6.414214  5.478774  12.545510  5.940785  5.639510
# 3  patient_307  6.502573  6.508156  5.648495  12.407083  6.414991  5.493800
# 4   patient_14  6.624505  6.911232  5.614099  10.777103  6.236386  5.512900
#
#      A4GALT     A4GNT      AA06    ...       ZWILCH     ZWINT      ZXDA  \
# 0  6.764585  6.094459  6.240895    ...     7.338461  8.616562  6.587933
# 1  6.723860  6.143284  6.256355    ...     8.138918  9.463643  6.233711
# 2  6.752736  6.001829  6.148274    ...     7.754430  9.229166  6.288666
# 3  6.912802  6.072980  6.318908    ...     6.582457  8.851282  6.672033
# 4  7.178968  6.088447  6.091908    ...     7.176397  7.618780  6.086676
#
#        ZXDB      ZXDC    ZYG11A     ZYG11B        ZYX     ZZEF1      ZZZ3
# 0  6.034539  7.525232  5.847143   9.426022  10.027414  8.438376  8.853557
# 1  6.174691  8.169813  5.988549   9.988564  11.577409  8.672737  9.205295
# 2  5.957426  8.148327  6.190679   9.531540  11.180062  8.484453  8.856021
# 3  6.194203  7.576931  6.422759   9.057685  10.062035  8.508903  7.742661
# 4  6.096177  7.251395  6.090243  10.298209   9.443150  8.204315  8.606522
#
# [5 rows x 19336 columns]

# %%
dfPhenotypes = pd.read_csv("sc1_Phase1_GE_Phenotype.tsv",sep="\t")
dfPhenotypes = dfPhenotypes.replace(r'^\s*$', np.nan, regex=True)
dfPhenotypes
# Out:
#        PATIENTID     SEX      RACE WHO_GRADING        CANCER_TYPE
# 0    patient_290     NaN       NaN          II        ASTROCYTOMA
# 1    patient_394     NaN       NaN         NaN                GBM
# 2     patient_81     NaN       NaN         III        ASTROCYTOMA
# 3    patient_307     NaN       NaN         NaN       UNCLASSIFIED
# 4     patient_14     NaN       NaN         NaN                GBM
# 5    patient_427     NaN       NaN         NaN                GBM
# 6     patient_87     NaN       NaN         NaN                GBM
# 7    patient_218     NaN       NaN         NaN                GBM
# 8    patient_102     NaN       NaN         NaN                GBM
# 9    patient_293     NaN       NaN         NaN                GBM
# 10   patient_341     NaN       NaN          II        ASTROCYTOMA
# 11   patient_212     NaN       NaN         NaN                GBM
# 12    patient_43     NaN       NaN         III        ASTROCYTOMA
# 13   patient_285     NaN       NaN         NaN                GBM
# 14   patient_371     NaN       NaN         NaN                GBM
# 15   patient_337     NaN       NaN         NaN                GBM
# 16   patient_244     NaN       NaN         NaN                GBM
# 17   patient_228     NaN       NaN         NaN                GBM
# 18   patient_471     NaN       NaN         NaN                GBM
# 19   patient_257     NaN       NaN         NaN                GBM
# 20   patient_178     NaN       NaN         III        ASTROCYTOMA
# 21   patient_603     NaN       NaN          II        ASTROCYTOMA
# 22   patient_500     NaN       NaN          II  OLIGODENDROGLIOMA
# 23   patient_420     NaN       NaN          II        ASTROCYTOMA
# 24   patient_353     NaN       NaN         NaN                GBM
# 25    patient_77     NaN       NaN         NaN                GBM
# 26   patient_265     NaN       NaN         NaN                GBM
# 27   patient_531     NaN       NaN         NaN                GBM
# 28   patient_403     NaN       NaN         III        ASTROCYTOMA
# 29   patient_201     NaN       NaN          II  OLIGODENDROGLIOMA
# ..           ...     ...       ...         ...                ...
# 347  patient_384  FEMALE     WHITE          II        ASTROCYTOMA
# 348   patient_76     NaN       NaN         III        ASTROCYTOMA
# 349  patient_631  FEMALE     WHITE          IV                GBM
# 350  patient_242    MALE     WHITE         III        ASTROCYTOMA
# 351  patient_547    MALE     WHITE          II        ASTROCYTOMA
# 352  patient_135     NaN       NaN          IV                GBM
# 353  patient_249    MALE     WHITE          II        ASTROCYTOMA
# 354   patient_10     NaN       NaN          IV                GBM
# 355  patient_145     NaN       NaN          IV                GBM
# 356  patient_665    MALE     WHITE          IV                GBM
# 357   patient_45     NaN       NaN          IV                GBM
# 358  patient_464     NaN       NaN          IV                GBM
# 359   patient_75    MALE     WHITE          IV                GBM
# 360  patient_122    MALE     WHITE          II        ASTROCYTOMA
# 361   patient_35  FEMALE     WHITE         III  OLIGODENDROGLIOMA
# 362  patient_120    MALE     WHITE          II        ASTROCYTOMA
# 363  patient_658    MALE     WHITE         III  OLIGODENDROGLIOMA
# 364  patient_401    MALE     WHITE          IV                GBM
# 365  patient_300    MALE     WHITE         III        ASTROCYTOMA
# 366  patient_382    MALE     WHITE         NaN        ASTROCYTOMA
# 367  patient_520    MALE     WHITE         III        ASTROCYTOMA
# 368   patient_71    MALE     WHITE         III  OLIGODENDROGLIOMA
# 369  patient_317  FEMALE     WHITE         III        ASTROCYTOMA
# 370  patient_378    MALE     WHITE         III            UNKNOWN
# 371  patient_410  FEMALE     WHITE         III        ASTROCYTOMA
# 372  patient_586  FEMALE     WHITE         III        ASTROCYTOMA
# 373   patient_22    MALE     WHITE          IV                GBM
# 374  patient_202    MALE     WHITE          IV                GBM
# 375  patient_497  FEMALE     WHITE          IV                GBM
# 376  patient_432    MALE  HISPANIC         NaN                GBM
#
# [377 rows x 5 columns]

# %%
dfs = [dfFeatures, dfPhenotypes, dfOutcomes] 
from functools import partial 
outer_merge = partial(pd.merge, how='outer') 
reduce(outer_merge, dfs)
dfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8625b9c563eb> in <module>
#       2 from functools import partial
#       3 outer_merge = partial(pd.merge, how='outer')
# ----> 4 reduce(outer_merge, dfs)
#       5 dfs
#
# NameError: name 'reduce' is not defined
