# %%
import pandas as pd
import numpy as np

dfOutcomes = pd.read_csv("sc1_Phase1_GE_Outcome.tsv",sep="\t")
dfOutcomes.head()
# Out:
#      PATIENTID  SURVIVAL_STATUS
# 0  patient_290                1
# 1  patient_394                1
# 2   patient_81                1
# 3  patient_307                1
# 4   patient_14                1

# %%
dfFeatures = pd.read_csv("sc1_Phase1_GE_FeatureMatrix.tsv",sep="\t")
dfFeatures.head()
# Out:
#      PATIENTID      A1BG  A1BG.AS1      A1CF        A2M   A2M.AS1     A2ML1  \
# 0  patient_290  6.557793  6.453623  5.302909  12.530607  6.082401  5.667769
# 1  patient_394  6.323015  6.305724  5.552097  13.000489  6.263721  5.347906
# 2   patient_81  6.669421  6.414214  5.478774  12.545510  5.940785  5.639510
# 3  patient_307  6.502573  6.508156  5.648495  12.407083  6.414991  5.493800
# 4   patient_14  6.624505  6.911232  5.614099  10.777103  6.236386  5.512900
#
#      A4GALT     A4GNT      AA06    ...       ZWILCH     ZWINT      ZXDA  \
# 0  6.764585  6.094459  6.240895    ...     7.338461  8.616562  6.587933
# 1  6.723860  6.143284  6.256355    ...     8.138918  9.463643  6.233711
# 2  6.752736  6.001829  6.148274    ...     7.754430  9.229166  6.288666
# 3  6.912802  6.072980  6.318908    ...     6.582457  8.851282  6.672033
# 4  7.178968  6.088447  6.091908    ...     7.176397  7.618780  6.086676
#
#        ZXDB      ZXDC    ZYG11A     ZYG11B        ZYX     ZZEF1      ZZZ3
# 0  6.034539  7.525232  5.847143   9.426022  10.027414  8.438376  8.853557
# 1  6.174691  8.169813  5.988549   9.988564  11.577409  8.672737  9.205295
# 2  5.957426  8.148327  6.190679   9.531540  11.180062  8.484453  8.856021
# 3  6.194203  7.576931  6.422759   9.057685  10.062035  8.508903  7.742661
# 4  6.096177  7.251395  6.090243  10.298209   9.443150  8.204315  8.606522
#
# [5 rows x 19336 columns]

# %%
dfPhenotypes = pd.read_csv("sc1_Phase1_GE_Phenotype.tsv",sep="\t")
dfPhenotypes = dfPhenotypes.replace(r'^\s*$', np.nan, regex=True)
dfPhenotypes.head()
# Out:
#      PATIENTID  SEX RACE WHO_GRADING   CANCER_TYPE
# 0  patient_290  NaN  NaN          II   ASTROCYTOMA
# 1  patient_394  NaN  NaN         NaN           GBM
# 2   patient_81  NaN  NaN         III   ASTROCYTOMA
# 3  patient_307  NaN  NaN         NaN  UNCLASSIFIED
# 4   patient_14  NaN  NaN         NaN           GBM

# %%
dfs = pd.merge(dfPhenotypes,dfOutcomes,how="inner",on="PATIENTID")
dfMerged = pd.merge(dfs,dfFeatures,how="inner",on="PATIENTID")
dfMerged.head()
# Out:
#      PATIENTID  SEX RACE WHO_GRADING   CANCER_TYPE  SURVIVAL_STATUS      A1BG  \
# 0  patient_290  NaN  NaN          II   ASTROCYTOMA                1  6.557793
# 1  patient_394  NaN  NaN         NaN           GBM                1  6.323015
# 2   patient_81  NaN  NaN         III   ASTROCYTOMA                1  6.669421
# 3  patient_307  NaN  NaN         NaN  UNCLASSIFIED                1  6.502573
# 4   patient_14  NaN  NaN         NaN           GBM                1  6.624505
#
#    A1BG.AS1      A1CF        A2M    ...       ZWILCH     ZWINT      ZXDA  \
# 0  6.453623  5.302909  12.530607    ...     7.338461  8.616562  6.587933
# 1  6.305724  5.552097  13.000489    ...     8.138918  9.463643  6.233711
# 2  6.414214  5.478774  12.545510    ...     7.754430  9.229166  6.288666
# 3  6.508156  5.648495  12.407083    ...     6.582457  8.851282  6.672033
# 4  6.911232  5.614099  10.777103    ...     7.176397  7.618780  6.086676
#
#        ZXDB      ZXDC    ZYG11A     ZYG11B        ZYX     ZZEF1      ZZZ3
# 0  6.034539  7.525232  5.847143   9.426022  10.027414  8.438376  8.853557
# 1  6.174691  8.169813  5.988549   9.988564  11.577409  8.672737  9.205295
# 2  5.957426  8.148327  6.190679   9.531540  11.180062  8.484453  8.856021
# 3  6.194203  7.576931  6.422759   9.057685  10.062035  8.508903  7.742661
# 4  6.096177  7.251395  6.090243  10.298209   9.443150  8.204315  8.606522
#
# [5 rows x 19341 columns]

# %%
from sklearn.feature_selection import GenericUnivariateSelect, chi2, SelectKBest, f_regression, RFE, mutual_info_classif
dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'UNKNOWN']
dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'UNCLASSIFIED']
dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'MIXED']
#dfMerged = dfMerged[dfMerged.CANCER_TYPE != 'OLIGODENDROGLIOMA']
X = dfMerged
X = X.drop(columns=['PATIENTID','SEX','RACE','WHO_GRADING','CANCER_TYPE','SURVIVAL_STATUS'])
y = dfMerged.iloc[:,4]
y.value_counts()
# Out:
# GBM                  162
# ASTROCYTOMA          110
# OLIGODENDROGLIOMA     47
# Name: CANCER_TYPE, dtype: int64

# %%
bestfeatures = SelectKBest(score_func=chi2, k=100)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Genes','Score']  #naming the dataframe columns
print(featureScores.nlargest(100,'Score'))  #print 10 best features
# Out:
#            Genes      Score
# 2940      CHI3L1  78.220016
# 13638       PTX3  63.244786
# 3311      COL3A1  56.246309
# 7243      IGFBP2  52.011102
# 356          ADM  50.634469
# 9952         LTF  48.634844
# 3299      COL1A1  47.932590
# 16888      TIMP1  47.115005
# 13067      POSTN  46.852636
# 4800        EMP3  46.719188
# 11543       NNMT  43.499630
# 742        ANXA1  42.232112
# 3300      COL1A2  37.208754
# 9959         LUM  36.829591
# 3657      CTHRC1  34.161154
# 10312       MCUB  32.336354
# 3324      COL6A3  31.998668
# 18210      VEGFA  31.629033
# 2527       CD163  31.505910
# 12468       PDPN  31.031185
# 10391      MEOX2  30.684337
# 3313      COL4A2  29.508827
# 2941      CHI3L2  29.442405
# 14592     S100A8  29.366611
# 4997      ETNPPL  28.582514
# 8230       LAMB1  28.435151
# 15803       SOD2  28.061099
# 9777       LOXL1  28.024006
# 6327       GPR17  27.979344
# 13986       RBP1  27.049726
# ...          ...        ...
# 3011       CHST9  19.436778
# 5897     GALNT13  19.407953
# 10487        MGP  19.279735
# 7978      KISS1R  19.021272
# 507       AKR1C3  18.878972
# 2939        CHGB  18.550610
# 8606   LINC00844  18.462640
# 7239     IGF2BP3  18.461284
# 746        ANXA2  18.386038
# 2449        CCL2  18.348074
# 3126       CLIC1  18.137449
# 2262        CAV1  17.637122
# 4160      DIRAS3  17.623908
# 12591    PHACTR3  17.596224
# 15972     SPOCD1  17.570203
# 12815       PLAT  17.395364
# 15689     SNAP91  17.327823
# 8686   LINC01088  17.284226
# 3257       CNTN1  17.041570
# 3728      CXCL14  17.028811
# 16785      TGFBI  16.850788
# 15658      SMOC1  16.841445
# 1858         C1S  16.778804
# 5133     FAM129A  16.609088
# 11159      NAMPT  16.576455
# 639       ANGPT2  16.526990
# 15645      SMIM3  16.477702
# 14930   SERPINH1  16.307356
# 3323      COL6A2  16.301862
# 12899       PLP2  16.229568
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
Vals= featureScores.nlargest(7,'Score')  #print 10 best features
xVal = Vals['Genes']
yVal = Vals['Score']
plt.plot(xVal,yVal)  #print 10 best features
plt.show()

# %%
selCols = pd.Series(['CANCER_TYPE'])
dfSelectedY = dfMerged.loc[:,selCols]
dfSelectedX = dfMerged.loc[:,xVal[0:]]


import seaborn as sns
corrMap = dfSelectedX.corr()
sns.heatmap(corrMap)

# %%
dfSelectedX = dfSelectedX.drop(columns=['COL3A1','IGFBP2'])
corrMap = dfSelectedX.corr()
sns.heatmap(corrMap)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(dfSelectedX, dfSelectedY, test_size=0.10, random_state=0)

from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression(multi_class='ovr',solver='lbfgs')
logisticRegr.fit(x_train, y_train)

predictions = logisticRegr.predict(x_test)
# Use score method to get accuracy of model
#print(y_test)

predY = pd.DataFrame(predictions,index= y_test.index, columns=['Predicted_type'])
#print(predY)

finalPred = pd.concat([y_test,predY],axis=1)
print(finalPred)

score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
#            CANCER_TYPE Predicted_type
# 372        ASTROCYTOMA    ASTROCYTOMA
# 324                GBM            GBM
# 16                 GBM            GBM
# 82   OLIGODENDROGLIOMA    ASTROCYTOMA
# 271  OLIGODENDROGLIOMA            GBM
# 80   OLIGODENDROGLIOMA    ASTROCYTOMA
# 295                GBM            GBM
# 218                GBM            GBM
# 223        ASTROCYTOMA    ASTROCYTOMA
# 253        ASTROCYTOMA            GBM
# 81                 GBM            GBM
# 129        ASTROCYTOMA    ASTROCYTOMA
# 175                GBM            GBM
# 306                GBM            GBM
# 297                GBM            GBM
# 75                 GBM            GBM
# 169  OLIGODENDROGLIOMA    ASTROCYTOMA
# 327                GBM            GBM
# 84   OLIGODENDROGLIOMA            GBM
# 27                 GBM            GBM
# 241        ASTROCYTOMA    ASTROCYTOMA
# 214                GBM            GBM
# 193  OLIGODENDROGLIOMA    ASTROCYTOMA
# 233                GBM            GBM
# 315        ASTROCYTOMA            GBM
# 255                GBM    ASTROCYTOMA
# 366        ASTROCYTOMA            GBM
# 8                  GBM            GBM
# 7                  GBM            GBM
# 348        ASTROCYTOMA    ASTROCYTOMA
# 309        ASTROCYTOMA    ASTROCYTOMA
# 23         ASTROCYTOMA    ASTROCYTOMA
# 0.6875
# c:\users\yq1012\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#try adding categorical features to the training - don't very little info in the categorical columns
#try kfold cross validation
#at this point, oligodendroglyoma has very little data so not included in the classifier
